# %%
# %pip install text-to-speech
from text_to_speech import speak
speak("Merhaba arkadaşlar Python dersi nasıl gidiyor", "tr", save=True, file="merhaba.mp3", speak=True)
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.10/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/dogukan/Desktop/my_package/deneme.ipynb Cell 1' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/dogukan/Desktop/my_package/deneme.ipynb#ch0000001?line=0'>1</a> get_ipython().run_line_magic('pip', 'install text-to-speech')
#       <a href='vscode-notebook-cell:/Users/dogukan/Desktop/my_package/deneme.ipynb#ch0000001?line=1'>2</a> from text_to_speech import speak
# ...
